# %% [markdown]
# ## Project 2 Notebook - 8/12/2020

# %% [markdown]
# ### Scott, Reuben, Javier, Sara

# %%
# Nasdaq Predictive Model

# %%
# Import Dependencies

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
# Read in NASDAQ 1 yr Data (July 2019 - July 2020)

# %%
nasdaq = pd.read_csv('final-model-data.csv')

# %%
nasdaq.tail()
# Out:
#        Symbol       Date  Open  High    Low  Close  Volume
# 947076   TRUE  20-Jul-20  2.96  3.01    2.9  2.985  478800
# 947077   TRUE  21-Jul-20  3.02  3.05  2.905   2.95  813200
# 947078   TRUE  22-Jul-20  2.92     3   2.92   2.95  581100
# 947079   TRUE  23-Jul-20  2.95  2.99   2.88  2.935  424800
# 947080   TRUE  24-Jul-20  2.94  2.94  2.825   2.87  402000

# %% [markdown]
# ## Cleaning the Data

# %%
# Change the Close column to Float

# %%
nasdaq_2 = nasdaq[nasdaq['Close']!= 'Close']

# %%
# Change the Close column values from objects to a floats

# %%
nasdaq_2['Close2'] = nasdaq_2['Close'].astype(float)

# %%
# One of the rows is named "Close" the 'for_loop' below idenifies that problem

# %%
for c_value in nasdaq['Close']:
    if (type(c_value)== str):
        print(c_value)
# Out:
# .374
# 26.2946
# 26.3627
# 26.3738
# 26.4422
# 26.3
# 26.56
# 26.45
# 26.45
# 26.5235
# 26.59
# 26.5
# 26.5
# 26.4
# 26.4
# 26.6093
# 26.575
# 26.45
# 26.35
# 26.328
# 26.5634
# 26.5075
# 26.53
# 26.53
# 26.53
# 26.3136
# 26.08
# 25.9953
# 26.0001
# 25.88
# 25.85
# 25.9918
# 25.9626
# 25.9626
# 25.9626
# 25.95
# 26.14
# 25.9377
# 25.95
# 26.05
# 25.9
# 25.9763
# 25.945
# 25.75
# 26.11
# 25.84
# 25.85
# 25.85
# 26.0514
# 26
# 26
# 26.05
# 26.05
# 26.38
# 26.461
# 26.326
# 26.326
# 26.326
# 26.326
# 26.35
# 26.35
# 26.427
# 26.427
# 26.427
# 26.427
# 26.427
# 26.4347
# 26.3611
# 26.3803
# 26.2
# 26.2
# 26.35
# 26.35
# 26.5718
# 26.4403
# 26.3711
# 26.55
# 26.6992
# 26.35
# 26.35
# 26.55
# 26.425
# 26.528
# 26.6479
# 26.5
# 26.5
# 26.5
# 26.41
# 26.69
# 26
# 26
# 26.1358
# 26.25
# 26.5768
# 26.5768
# 26.5509
# 26.5
# 25.8
# 25.84
# 25.45
# 25.45
# 25.45
# 25.76
# 25.456
# 25.97
# 25.6
# 25.8536
# 25.4
# 23.6
# 23.96
# 23.756
# 22.08
# 19.42
# 18.4089
# 20
# 19.98
# 21
# 21.5
# 23.7075
# 22.64
# 22.5
# 21.5
# 21.5
# 20.5
# 20.2
# 22.015
# 20.7686
# 21.25
# 22
# 22
# 21.95
# 24
# 22.275
# 21.5
# 21.8085
# 21.8085
# 22.48
# 22.5
# 22.5
# 22.7227
# 23
# 23.0001
# 24
# 24
# 24
# 22.77
# 24
# 23.625
# 23.75
# 59.77
# 58.44
# 58.56
# 57.55
# 56.96
# 56.83
# 55.65
# 56.12
# 56.01
# 57.63
# 57.64
# 58.22
# 58.22
# 58.34
# 57.95
# 55.68
# 56.93
# 57.08
# 57.94
# 57.36
# 56.88
# 57.93
# 58.81
# 57.63
# 57.4
# 58.83
# 58.54
# 58.61
# 57.21
# 56.58
# 56.81
# 56.81
# 56.86
# 57.11
# 57.61
# 57.4
# 57.4
# 57.83
# 57.99
# 56.77
# 56.79
# 56.85
# 56.83
# 57.04
# 58.34
# 58.33
# 58.9
# 59.63
# 59.31
# 59.31
# 59.15
# 58.31
# 58.08
# 56.84
# 56.51
# 57
# 55.46
# 55.64
# 54.31
# 54.39
# 55.86
# 57.48
# 56.37
# 55.2
# 54.82
# 55.6
# 56.76
# 57.72
# 56.65
# 56.65
# 56.3
# 51.94
# 52.1
# 53.01
# 52.5
# 49.94
# 49.72
# 50.87
# 48.97
# 51.62
# 49.25
# 49.55
# 47.9
# 47.65
# 44.97
# 45.49
# 44.41
# 40.62
# 43.84
# 39.8
# 44.66
# 41.65
# 42.81
# 39.12
# 39.26
# 41.58
# 41.08
# 44.82
# 42.42
# 41.75
# 41.99
# 39.62
# 40.37
# 38.63
# 41.73
# 41.71
# 43.71
# 45.39
# 45.39
# 43.17
# 44.04
# 41.13
# 41.58
# 43.97
# 43.09
# 42.75
# 43.07
# 43.98
# 44.27
# 46.15
# 47.64
# 52.04
# 45.78
# 45.37
# 45.53
# 46.37
# 44.31
# 44.7
# 46.56
# 44.58
# 43.67
# 42.27
# 42.52
# 43.5
# 45.46
# 44.48
# 44.93
# 45.48
# 45.69
# 45.69
# 46.61
# 48.93
# 48.3
# 48.29
# 47.91
# 49.25
# 49.98
# 50.96
# 52.83
# 53.57
# 51.42
# 50.78
# 46.35
# 47.01
# 47.77
# 49.15
# 47.475
# 47.31
# 46.69
# 47.65
# 47.51
# 46.27
# 46.6
# 45.72
# 48.57
# 48.82
# 47.46
# 47.59
# 47.59
# 48.19
# 46.96
# 47.37
# 46.1
# 47.13
# 47.24
# 48.16
# 49.34
# 49.44
# 49.7
# 48.58
# 50.32
# 50.13
# 50.43
# 49.94
# 1.16
# 1.14
# 1.23
# 1.23
# 1.26
# 1.24
# 1.16
# 1.29
# 1.18
# 1.14
# 1.139
# 1.1
# 1.14
# 1.14
# 1.12

# %%
# Take the Nasdaq dataframe and drop all columns except "Close2"...one with the float values

# %%
nasdaq_2.drop(columns=['Open', 'High', 'Low', 'Volume', 'Close'], inplace=True)
nasdaq_2.tail()
# Out:
#        Symbol       Date  Close2
# 947076   TRUE  20-Jul-20   2.985
# 947077   TRUE  21-Jul-20   2.950
# 947078   TRUE  22-Jul-20   2.950
# 947079   TRUE  23-Jul-20   2.935
# 947080   TRUE  24-Jul-20   2.870

# %%
nasdaq_2.set_index(['Symbol', 'Date'], inplace =True)

# %%
nasdaq_2 = nasdaq_2.groupby('Symbol').pct_change()

# %%
nasdaq_2.head()
# Out:
#                     Close2
# Symbol Date
# AACG   17-Oct-19       NaN
#        18-Oct-19 -0.037989
#        21-Oct-19  0.028247
#        22-Oct-19 -0.022032
#        23-Oct-19  0.028034

# %%
# Drop NaN values and Rename columns to clean up Dataframe, then sort the dates

# %%
nasdaq_2 = nasdaq_2.dropna()

# %%
nasdaq_2 = nasdaq_2.rename(columns={'Close2': 'Returns'})

# %%
nasdaq_2 = nasdaq_2.sort_values('Date')

# %%
nasdaq_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 943004 entries, (SCHN, 1-Apr-20) to (DOMO, 9-Sep-19)
# Data columns (total 1 columns):
# Returns    943004 non-null float64
# dtypes: float64(1)
# memory usage: 10.8+ MB

# %% [markdown]
# ## Cleaned DataFrame - Ticker, Date, Returns by Day

# %%
nasdaq_2.head()
# Out:
#                   Returns
# Symbol Date
# SCHN   1-Apr-20 -0.039877
# FIVN   1-Apr-20 -0.035574
# PFBC   1-Apr-20 -0.071851
# SALM   1-Apr-20 -0.116382
# JCS    1-Apr-20 -0.044843

# %%
#nasdaq = pd.read_csv('final-model-data.csv')

# %%
#nasdaq.drop(columns=['Open', 'High', 'Low', 'Volume'], inplace=True)

# %%
#nasdaq_closed = nasdaq[nasdaq['Close']!= 'Close']
#nasdaq_closed['Close'] = nasdaq_closed['Close'].astype(float)

# %%
#nasdaq_closed.set_index(['Symbol', 'Date'], inplace =True)

# %%
#nasdaq_cleaned = pd.merge(nasdaq_closed, nasdaq_2, left_index=True, right_index=True, how='outer')

# %%
#nasdaq_cleaned.head()

# %%
#temp_df = nasdaq_cleaned[nasdaq_cleaned['Symbol']==AACG]
#temp_df = nasdaq_cleaned[nasdaq_cleaned.index.get_level_vaues()==AACG]

# %% [markdown]
# ## Random Forest Model Creation

# %%
# Import libraries and dependencies
import pandas as pd
import numpy as np
from pathlib import Path
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Set short and long windows
short_window = 1
long_window = 10

# Construct a `Fast` and `Slow` Exponential Moving Average from short and long windows, respectively
nasdaq_2['fast_close'] = nasdaq_2['Returns'].ewm(halflife=short_window).mean()
nasdaq_2['slow_close'] = nasdaq_2['Returns'].ewm(halflife=long_window).mean()

# Construct a crossover trading signal
nasdaq_2['crossover_long'] = np.where(nasdaq_2['fast_close'] > nasdaq_2['slow_close'], 1.0, 0.0)
nasdaq_2['crossover_short'] = np.where(nasdaq_2['fast_close'] < nasdaq_2['slow_close'], -1.0, 0.0)
nasdaq_2['crossover_signal'] = nasdaq_2['crossover_long'] + nasdaq_2['crossover_short']

nasdaq_2.head()
# Out:
#                   Returns  fast_close  slow_close  crossover_long  \
# Symbol Date
# SCHN   1-Apr-20 -0.039877   -0.039877   -0.039877             0.0
# FIVN   1-Apr-20 -0.035574   -0.037009   -0.037651             1.0
# PFBC   1-Apr-20 -0.071851   -0.056919   -0.049850             0.0
# SALM   1-Apr-20 -0.116382   -0.088632   -0.068250             0.0
# JCS    1-Apr-20 -0.044843   -0.066031   -0.062898             0.0
#
#                  crossover_short  crossover_signal
# Symbol Date
# SCHN   1-Apr-20              0.0               0.0
# FIVN   1-Apr-20              0.0               1.0
# PFBC   1-Apr-20             -1.0              -1.0
# SALM   1-Apr-20             -1.0              -1.0
# JCS    1-Apr-20             -1.0              -1.0

# %% [markdown]
# ## Plot the Nasdaq closing, fast & slow moving average prices

# %%
nasdaq_2[['Returns', 'fast_close', 'slow_close']].plot(kind='line', figsize=(20,10))
#nasdaq_2[['Returns']].plot(kind='line', figsize=(20,10))

# %% [markdown]
# ## Set the short term and long term MA volatility windows

# %%
# Set short and long volatility windows
short_vol_window = 1
long_vol_window = 10

# Construct a `Fast` and `Slow` Exponential Moving Average from short and long windows, respectively
nasdaq_2['fast_vol'] = nasdaq_2['Returns'].ewm(halflife=short_vol_window).std()
nasdaq_2['slow_vol'] = nasdaq_2['Returns'].ewm(halflife=long_vol_window).std()

# Construct a crossover trading signal
nasdaq_2['vol_trend_long'] = np.where(nasdaq_2['fast_vol'] < nasdaq_2['slow_vol'], 1.0, 0.0)
nasdaq_2['vol_trend_short'] = np.where(nasdaq_2['fast_vol'] > nasdaq_2['slow_vol'], -1.0, 0.0) 
nasdaq_2['vol_trend_signal'] = nasdaq_2['vol_trend_long'] + nasdaq_2['vol_trend_short']

nasdaq_2.head()
# Out:
#                   Returns  fast_close  slow_close  crossover_long  \
# Symbol Date
# SCHN   1-Apr-20 -0.039877   -0.039877   -0.039877             0.0
# FIVN   1-Apr-20 -0.035574   -0.037009   -0.037651             1.0
# PFBC   1-Apr-20 -0.071851   -0.056919   -0.049850             0.0
# SALM   1-Apr-20 -0.116382   -0.088632   -0.068250             0.0
# JCS    1-Apr-20 -0.044843   -0.066031   -0.062898             0.0
#
#                  crossover_short  crossover_signal  fast_vol  slow_vol  \
# Symbol Date
# SCHN   1-Apr-20              0.0               0.0       NaN       NaN
# FIVN   1-Apr-20              0.0               1.0  0.003043  0.003043
# PFBC   1-Apr-20             -1.0              -1.0  0.022877  0.020191
# SALM   1-Apr-20             -1.0              -1.0  0.040480  0.038020
# JCS    1-Apr-20             -1.0              -1.0  0.038820  0.034158
#
#                  vol_trend_long  vol_trend_short  vol_trend_signal
# Symbol Date
# SCHN   1-Apr-20             0.0              0.0               0.0
# FIVN   1-Apr-20             0.0             -1.0              -1.0
# PFBC   1-Apr-20             0.0             -1.0              -1.0
# SALM   1-Apr-20             0.0             -1.0              -1.0
# JCS    1-Apr-20             0.0             -1.0              -1.0

# %% [markdown]
# ## Bollinger Band Window

# %%
# Set bollinger band window
bollinger_window = 20

# Calculate rolling mean and standard deviation
nasdaq_2['bollinger_mid_band'] = nasdaq_2['Returns'].rolling(window=bollinger_window).mean()
nasdaq_2['bollinger_std'] = nasdaq_2['Returns'].rolling(window=20).std()

# Calculate upper and lowers bands of bollinger band
nasdaq_2['bollinger_upper_band']  = nasdaq_2['bollinger_mid_band'] + (nasdaq_2['bollinger_std'] * 1)
nasdaq_2['bollinger_lower_band']  = nasdaq_2['bollinger_mid_band'] - (nasdaq_2['bollinger_std'] * 1)

# Calculate bollinger band trading signal
nasdaq_2['bollinger_long'] = np.where(nasdaq_2['Returns'] < nasdaq_2['bollinger_lower_band'], 1.0, 0.0)
nasdaq_2['bollinger_short'] = np.where(nasdaq_2['Returns'] > nasdaq_2['bollinger_upper_band'], -1.0, 0.0)
nasdaq_2['bollinger_signal'] = nasdaq_2['bollinger_long'] + nasdaq_2['bollinger_short']

nasdaq_2.head()
# Out:
#                   Returns  fast_close  slow_close  crossover_long  \
# Symbol Date
# SCHN   1-Apr-20 -0.039877   -0.039877   -0.039877             0.0
# FIVN   1-Apr-20 -0.035574   -0.037009   -0.037651             1.0
# PFBC   1-Apr-20 -0.071851   -0.056919   -0.049850             0.0
# SALM   1-Apr-20 -0.116382   -0.088632   -0.068250             0.0
# JCS    1-Apr-20 -0.044843   -0.066031   -0.062898             0.0
#
#                  crossover_short  crossover_signal  fast_vol  slow_vol  \
# Symbol Date
# SCHN   1-Apr-20              0.0               0.0       NaN       NaN
# FIVN   1-Apr-20              0.0               1.0  0.003043  0.003043
# PFBC   1-Apr-20             -1.0              -1.0  0.022877  0.020191
# SALM   1-Apr-20             -1.0              -1.0  0.040480  0.038020
# JCS    1-Apr-20             -1.0              -1.0  0.038820  0.034158
#
#                  vol_trend_long  vol_trend_short  vol_trend_signal  \
# Symbol Date
# SCHN   1-Apr-20             0.0              0.0               0.0
# FIVN   1-Apr-20             0.0             -1.0              -1.0
# PFBC   1-Apr-20             0.0             -1.0              -1.0
# SALM   1-Apr-20             0.0             -1.0              -1.0
# JCS    1-Apr-20             0.0             -1.0              -1.0
#
#                  bollinger_mid_band  bollinger_std  bollinger_upper_band  \
# Symbol Date
# SCHN   1-Apr-20                 NaN            NaN                   NaN
# FIVN   1-Apr-20                 NaN            NaN                   NaN
# PFBC   1-Apr-20                 NaN            NaN                   NaN
# SALM   1-Apr-20                 NaN            NaN                   NaN
# JCS    1-Apr-20                 NaN            NaN                   NaN
#
#                  bollinger_lower_band  bollinger_long  bollinger_short  \
# Symbol Date
# SCHN   1-Apr-20                   NaN             0.0              0.0
# FIVN   1-Apr-20                   NaN             0.0              0.0
# PFBC   1-Apr-20                   NaN             0.0              0.0
# SALM   1-Apr-20                   NaN             0.0              0.0
# JCS    1-Apr-20                   NaN             0.0              0.0
#
#                  bollinger_signal
# Symbol Date
# SCHN   1-Apr-20               0.0
# FIVN   1-Apr-20               0.0
# PFBC   1-Apr-20               0.0
# SALM   1-Apr-20               0.0
# JCS    1-Apr-20               0.0

# %%
# Set x variable list of features
x_var_list = ['crossover_signal', 'vol_trend_signal', 'bollinger_signal']

# Filter by x-variable list
nasdaq_2[x_var_list].head()
# Out:
#                  crossover_signal  vol_trend_signal  bollinger_signal
# Symbol Date
# SCHN   1-Apr-20               0.0               0.0               0.0
# FIVN   1-Apr-20               1.0              -1.0               0.0
# PFBC   1-Apr-20              -1.0              -1.0               0.0
# SALM   1-Apr-20              -1.0              -1.0               0.0
# JCS    1-Apr-20              -1.0              -1.0               0.0

# %% [markdown]
# ## Shift the DataFrame by 1 day to calculate predicted returns from the previous day

# %%
# Shift DataFrame values by 1
nasdaq_2[x_var_list] = nasdaq_2[x_var_list].shift(1)
nasdaq_2[x_var_list].tail()
# Out:
#                  crossover_signal  vol_trend_signal  bollinger_signal
# Symbol Date
# KFRC   9-Sep-19              -1.0               1.0               0.0
# WYNN   9-Sep-19              -1.0               1.0               0.0
# STOK   9-Sep-19               1.0               1.0               0.0
# VTGN   9-Sep-19              -1.0              -1.0               1.0
# DOMO   9-Sep-19              -1.0              -1.0               0.0

# %%
# Drop NAs and replace positive/negative infinity values

nasdaq_2.dropna(subset=x_var_list, inplace=True)
nasdaq_2.dropna(subset=['Returns'], inplace=True)
nasdaq_2 = nasdaq_2.replace([np.inf, -np.inf], np.nan)
nasdaq_2.head()
# Out:
#                   Returns  fast_close  slow_close  crossover_long  \
# Symbol Date
# FIVN   1-Apr-20 -0.035574   -0.037009   -0.037651             1.0
# PFBC   1-Apr-20 -0.071851   -0.056919   -0.049850             0.0
# SALM   1-Apr-20 -0.116382   -0.088632   -0.068250             0.0
# JCS    1-Apr-20 -0.044843   -0.066031   -0.062898             0.0
# CIVB   1-Apr-20 -0.086898   -0.076630   -0.067622             0.0
#
#                  crossover_short  crossover_signal  fast_vol  slow_vol  \
# Symbol Date
# FIVN   1-Apr-20              0.0               0.0  0.003043  0.003043
# PFBC   1-Apr-20             -1.0               1.0  0.022877  0.020191
# SALM   1-Apr-20             -1.0              -1.0  0.040480  0.038020
# JCS    1-Apr-20             -1.0              -1.0  0.038820  0.034158
# CIVB   1-Apr-20             -1.0              -1.0  0.029917  0.031774
#
#                  vol_trend_long  vol_trend_short  vol_trend_signal  \
# Symbol Date
# FIVN   1-Apr-20             0.0             -1.0               0.0
# PFBC   1-Apr-20             0.0             -1.0              -1.0
# SALM   1-Apr-20             0.0             -1.0              -1.0
# JCS    1-Apr-20             0.0             -1.0              -1.0
# CIVB   1-Apr-20             1.0              0.0              -1.0
#
#                  bollinger_mid_band  bollinger_std  bollinger_upper_band  \
# Symbol Date
# FIVN   1-Apr-20                 NaN            NaN                   NaN
# PFBC   1-Apr-20                 NaN            NaN                   NaN
# SALM   1-Apr-20                 NaN            NaN                   NaN
# JCS    1-Apr-20                 NaN            NaN                   NaN
# CIVB   1-Apr-20                 NaN            NaN                   NaN
#
#                  bollinger_lower_band  bollinger_long  bollinger_short  \
# Symbol Date
# FIVN   1-Apr-20                   NaN             0.0              0.0
# PFBC   1-Apr-20                   NaN             0.0              0.0
# SALM   1-Apr-20                   NaN             0.0              0.0
# JCS    1-Apr-20                   NaN             0.0              0.0
# CIVB   1-Apr-20                   NaN             0.0              0.0
#
#                  bollinger_signal
# Symbol Date
# FIVN   1-Apr-20               0.0
# PFBC   1-Apr-20               0.0
# SALM   1-Apr-20               0.0
# JCS    1-Apr-20               0.0
# CIVB   1-Apr-20               0.0

# %% [markdown]
# ## Construct the dependent variable - daily returns greater than 0 == 1, else returns == 0

# %%
# Construct the dependent variable where if daily return is greater than 0, then 1, else, 0.
# Changing the target variable away from 0 introduces the problem of an imbalanced dataset

nasdaq_2['Positive Return'] = np.where(nasdaq_2['Returns'] > 0, 1.0, 0.0)
nasdaq_2.dropna(inplace=True)

# %%
nasdaq_3 = nasdaq_2.copy()
len(nasdaq_3)
# Out:
# 942985

# %%
# Create Target list column and Loop through the rows to find values that had over 5% jump in returns for the previous day

# %%
target_list = []
stoprw = len(nasdaq_3)
for rw in range(stoprw):
    if rw != stoprw:
        rwn = rw  
        if nasdaq_3['Returns'][rwn]> 0.02:
            target_list.append(1)
        else:
            target_list.append(0)
    else: 
        print("hit!")
        target_list.append(0)
nasdaq_3['Target'] = target_list

# %%
# Check to make sure Dataframe has all 900,000 values from the dataset

# %%
len(target_list)
# Out:
# 942985

# %%
len(nasdaq_3)
# Out:
# 942985

# %%
nasdaq_3['Target'] = target_list

# %% [markdown]
# ## NASDAQ_4 ???

# %%
nasdaq_4 = nasdaq_3.drop(['Returns','Positive Return'], axis=1)
nasdaq_4.head(3)
# Out:
#                  fast_close  slow_close  crossover_long  crossover_short  \
# Symbol Date
# BEAM   1-Apr-20   -0.098930   -0.070467             0.0             -1.0
# DAKT   1-Apr-20   -0.101189   -0.073347             0.0             -1.0
# HYACW  1-Apr-20   -0.050595   -0.067069             1.0              0.0
#
#                  crossover_signal  fast_vol  slow_vol  vol_trend_long  \
# Symbol Date
# BEAM   1-Apr-20              -1.0  0.050345  0.060417             1.0
# DAKT   1-Apr-20              -1.0  0.035707  0.058448             1.0
# HYACW  1-Apr-20              -1.0  0.066912  0.059690             0.0
#
#                  vol_trend_short  vol_trend_signal  bollinger_mid_band  \
# Symbol Date
# BEAM   1-Apr-20              0.0              -1.0           -0.064598
# DAKT   1-Apr-20              0.0               1.0           -0.067777
# HYACW  1-Apr-20             -1.0               1.0           -0.065998
#
#                  bollinger_std  bollinger_upper_band  bollinger_lower_band  \
# Symbol Date
# BEAM   1-Apr-20       0.055151             -0.009447             -0.119750
# DAKT   1-Apr-20       0.055483             -0.012295             -0.123260
# HYACW  1-Apr-20       0.057115             -0.008883             -0.123114
#
#                  bollinger_long  bollinger_short  bollinger_signal  Target
# Symbol Date
# BEAM   1-Apr-20             0.0              0.0               0.0       0
# DAKT   1-Apr-20             0.0              0.0               0.0       0
# HYACW  1-Apr-20             0.0             -1.0               0.0       0

# %%
# Look to see if the values need to be Standardized....all columns should be between 0 and 1.

# %%
nasdaq_4.max()
# Out:
# fast_close              40.974025
# slow_close               5.488104
# crossover_long           1.000000
# crossover_short          0.000000
# crossover_signal         1.000000
# fast_vol                50.179894
# slow_vol                20.847752
# vol_trend_long           1.000000
# vol_trend_short          0.000000
# vol_trend_signal         1.000000
# bollinger_mid_band       4.101838
# bollinger_std           18.323982
# bollinger_upper_band    22.424433
# bollinger_lower_band     0.050527
# bollinger_long           1.000000
# bollinger_short          0.000000
# bollinger_signal         1.000000
# Target                   1.000000
# dtype: float64

# %%
nasdaq_4.min()
# Out:
# fast_close             -6.010646e-01
# slow_close             -1.913387e-01
# crossover_long          0.000000e+00
# crossover_short        -1.000000e+00
# crossover_signal       -1.000000e+00
# fast_vol                0.000000e+00
# slow_vol                8.036743e-54
# vol_trend_long          0.000000e+00
# vol_trend_short        -1.000000e+00
# vol_trend_signal       -1.000000e+00
# bollinger_mid_band     -2.253245e-01
# bollinger_std           0.000000e+00
# bollinger_upper_band   -9.660491e-02
# bollinger_lower_band   -1.422802e+01
# bollinger_long          0.000000e+00
# bollinger_short        -1.000000e+00
# bollinger_signal       -1.000000e+00
# Target                  0.000000e+00
# dtype: float64

# %%
nv = ['fast_close', 'slow_close', 'fast_vol','slow_vol', 'bollinger_mid_band', 'bollinger_std', 'bollinger_upper_band']

# %% [markdown]
# ## Standardize columns

# %%
nas = nasdaq_4.copy()
stdrd = nasdaq_4[nv]
#standardizing using min max scaler
from sklearn import preprocessing
minmax = preprocessing.MinMaxScaler()
x_unstdrd = stdrd.values
x_stdrd = minmax.fit_transform(x_unstdrd)
nas[nv] = x_stdrd

# %% [markdown]
# ## Training the Model

# %%
# Construct training start and end dates
training_start = '2019-Jun-01'
training_end = '2020-Apr-29'
# Construct testing start and end dates
testing_start =  '2020-Apr-30'
testing_end = '2020-Jul-24'
# Print training and testing start/end dates
print(f"Training Start: {training_start}")
print(f"Training End: {training_end}")
print(f"Testing Start: {testing_start}")
print(f"Testing End: {testing_end}")
# Out:
# Training Start: 2019-Jun-01
# Training End: 2020-Apr-29
# Testing Start: 2020-Apr-30
# Testing End: 2020-Jul-24

# %%
# Target Variable
y = nas['Target']

# %%
X = nas.drop(['Target'],inplace=True, axis=1)
X = nas

# %%
X.columns
# Out:
# Index(['fast_close', 'slow_close', 'crossover_long', 'crossover_short',
#        'crossover_signal', 'fast_vol', 'slow_vol', 'vol_trend_long',
#        'vol_trend_short', 'vol_trend_signal', 'bollinger_mid_band',
#        'bollinger_std', 'bollinger_upper_band', 'bollinger_lower_band',
#        'bollinger_long', 'bollinger_short', 'bollinger_signal'],
#       dtype='object')

# %%
y
# Out:
# Symbol  Date
# BEAM    1-Apr-20    0
# DAKT    1-Apr-20    0
# HYACW   1-Apr-20    0
# GENE    1-Apr-20    0
# ESLT    1-Apr-20    0
# JCOM    1-Apr-20    0
# NDRA    1-Apr-20    0
# VYGR    1-Apr-20    0
# AEMD    1-Apr-20    0
# SAGE    1-Apr-20    0
# PSCI    1-Apr-20    0
# TCF     1-Apr-20    0
# CINF    1-Apr-20    0
# NDRAW   1-Apr-20    0
# NCSM    1-Apr-20    0
# ESGU    1-Apr-20    0
# NBSE    1-Apr-20    0
# SAMG    1-Apr-20    0
# BCYC    1-Apr-20    1
# NBTB    1-Apr-20    0
# PFBI    1-Apr-20    0
# ESGRP   1-Apr-20    0
# GEVO    1-Apr-20    0
# DAIO    1-Apr-20    0
# TCCO    1-Apr-20    0
# SAMAW   1-Apr-20    0
# VWOB    1-Apr-20    0
# FCAP    1-Apr-20    0
# CIZN    1-Apr-20    0
# CAMP    1-Apr-20    0
#                    ..
# FPXE    9-Sep-19    0
# LPCN    9-Sep-19    1
# WRLSR   9-Sep-19    0
# BJRI    9-Sep-19    1
# BCPC    9-Sep-19    1
# TWOU    9-Sep-19    1
# NEO     9-Sep-19    0
# ALDX    9-Sep-19    0
# PMTS    9-Sep-19    0
# NXTG    9-Sep-19    0
# WABC    9-Sep-19    1
# CMLS    9-Sep-19    1
# TMSR    9-Sep-19    1
# LSXMA   9-Sep-19    0
# LOACR   9-Sep-19    0
# TRVN    9-Sep-19    1
# GFNSL   9-Sep-19    0
# CCMP    9-Sep-19    0
# CSGP    9-Sep-19    0
# SMED    9-Sep-19    1
# CERC    9-Sep-19    1
# CHSCP   9-Sep-19    0
# SYNH    9-Sep-19    0
# MESO    9-Sep-19    0
# MSFT    9-Sep-19    0
# KFRC    9-Sep-19    0
# WYNN    9-Sep-19    1
# STOK    9-Sep-19    0
# VTGN    9-Sep-19    1
# DOMO    9-Sep-19    0
# Name: Target, Length: 942985, dtype: int64

# %%
# Check the Test data points 

#tst = nas[nas['Target']== 1]
#len(tst)

# %%
# Construct the X_train and y_train datasets
X_train = X.iloc[0:660102]
y_train = y.iloc[0:660102]

X_train
# Out:
# 411             1.0              0.0
# WVVIP  29-Jul-19    0.014700    0.032496             1.0              0.0
# CBAT   29-Jul-19    0.014279    0.032282             1.0              0.0
# FMHI   29-Jul-19    0.014354    0.032363             1.0              0.0
# CPRX   29-Jul-19    0.014308    0.032356             1.0              0.0
# MTCH   29-Jul-19    0.014281    0.032346             1.0              0.0
# IDCC   29-Jul-19    0.014144    0.032215             0.0             -1.0
# CHCO   29-Jul-19    0.014135    0.032152             0.0             -1.0
# GOOG   29-Jul-19    0.014191    0.032151             0.0             -1.0
# DGLY   29-Jul-19    0.013661    0.031604             0.0             -1.0
# SLGL   29-Jul-19    0.014331    0.032010             1.0              0.0
# FFIC   29-Jul-19    0.014150    0.031883             0.0             -1.0
# CYRXW  29-Jul-19    0.014304    0.032004             1.0              0.0
# ADP    29-Jul-19    0.014284    0.032022             1.0              0.0
# BPRN   29-Jul-19    0.014314    0.032078             1.0              0.0
# ISNS   29-Jul-19    0.014582    0.032379             1.0              0.0
#
#                   crossover_signal  fast_vol  slow_vol  vol_trend_long  \
# Symbol Date
# BEAM   1-Apr-20               -1.0  0.001003  0.002898             1.0
# DAKT   1-Apr-20               -1.0  0.000712  0.002804             1.0
# HYACW  1-Apr-20               -1.0  0.001333  0.002863             0.0
# GENE   1-Apr-20                1.0  0.001763  0.003095             0.0
# ESLT   1-Apr-20               -1.0  0.001492  0.002993             0.0
# JCOM   1-Apr-20               -1.0  0.001066  0.002876             1.0
# NDRA   1-Apr-20               -1.0  0.000817  0.002765             1.0
# VYGR   1-Apr-20                1.0  0.000830  0.002723             1.0
# AEMD   1-Apr-20               -1.0  0.000598  0.002640             1.0
# SAGE   1-Apr-20               -1.0  0.000575  0.002538             1.0
# PSCI   1-Apr-20               -1.0  0.000437  0.002440             1.0
# TCF    1-Apr-20               -1.0  0.000316  0.002346             1.0
# CINF   1-Apr-20                1.0  0.000653  0.002355             1.0
# NDRAW  1-Apr-20                1.0  0.000766  0.002455             1.0
# NCSM   1-Apr-20                1.0  0.002039  0.002805             0.0
# BEAM   1-Apr-20               0.0              -1.0            0.037144
# DAKT   1-Apr-20               0.0               1.0            0.036409
# HYACW  1-Apr-20              -1.0               1.0            0.036820
# GENE   1-Apr-20              -1.0              -1.0            0.035655
# ESLT   1-Apr-20              -1.0              -1.0            0.036486
# JCOM   1-Apr-20               0.0              -1.0            0.035957
# NDRA   1-Apr-20               0.0               1.0            0.036286
# VYGR   1-Apr-20               0.0               1.0            0.036098
# AEMD   1-Apr-20               0.0               1.0            0.035064
# SAGE   1-Apr-20               0.0               1.0            0.034666
# PSCI   1-Apr-20               0.0               1.0            0.034279
# TCF    1-Apr-20               0.0               1.0            0.034035
# CINF   1-Apr-20               0.0               1.0            0.033083
# NDRAW  1-Apr-20               0.0               1.0            0.033773
# NCSM   1-Apr-20              -1.0               1.0            0.031949
# ESGU   1-Apr-20              -1.0              -1.0            0.032692
# NBSE   1-Apr-20              -1.0              -1.0            0.032662
# SAMG   1-Apr-20               0.0              -1.0            0.034737
# BCYC   1-Apr-20              -1.0               1.0            0.035386
# NBTB   1-Apr-20               0.0              -1.0            0.036229
# PFBI   1-Apr-20               0.0               1.0            0.036663
# ESGRP  1-Apr-20               0.0               1.0            0.037014
# GEVO   1-Apr-20               0.0               1.0            0.035741
# DAIO   1-Apr-20              -1.0               1.0            0.037612
# TCCO   1-Apr-20               0.0              -1.0            0.037149
# SAMAW  1-Apr-20               0.0               1.0            0.037670
# VWOB   1-Apr-20               0.0               1.0            0.037904
# FCAP   1-Apr-20              -1.0               1.0            0.036897
# CIZN   1-Apr-20              -1.0              -1.0            0.037987
# CAMP   1-Apr-20              -1.0              -1.0            0.037881
# ...                           ...               ...                 ...
# DWFI   29-Jul-19              0.0               1.0            0.047519
# ALEC   29-Jul-19             -1.0               1.0            0.048368
# BRKS   29-Jul-19             -1.0              -1.0            0.048502
# RNDM   29-Jul-19              0.0              -1.0            0.048537
# DGICB  29-Jul-19              0.0               1.0            0.049257
# MLVF   29-Jul-19              0.0               1.0            0.050300
# CPTAG  29-Jul-19              0.0               1.0            0.050368
# DISCA  29-Jul-19              0.0               1.0            0.051052
# RTRX   29-Jul-19              0.0               1.0            0.050319
# GXGXW  29-Jul-19             -1.0               1.0            0.048992
# ELTK   29-Jul-19             -1.0              -1.0            0.049817
# CETX   29-Jul-19             -1.0              -1.0            0.049470
# RGEN   29-Jul-19             -1.0              -1.0            0.050291
# ALAC   29-Jul-19             -1.0              -1.0            0.050326
# LACQW  29-Jul-19             -1.0              -1.0            0.050605
# WVVIP  29-Jul-19              0.0              -1.0            0.051031
# CBAT   29-Jul-19              0.0               1.0            0.050944
# FMHI   29-Jul-19              0.0               1.0            0.050931
# CPRX   29-Jul-19              0.0               1.0            0.051052
# MTCH   29-Jul-19              0.0               1.0            0.051238
# IDCC   29-Jul-19              0.0               1.0            0.051011
# CHCO   29-Jul-19              0.0               1.0            0.050187
# GOOG   29-Jul-19              0.0               1.0            0.050110
# DGLY   29-Jul-19              0.0               1.0            0.049481
# SLGL   29-Jul-19             -1.0               1.0            0.049742
# WVVIP  29-Jul-19       0.001979              0.005699             -0.040764
# CBAT   29-Jul-19       0.001988              0.005691             -0.041317
# FMHI   29-Jul-19       0.001988              0.005688             -0.041367
# CPRX   29-Jul-19       0.001981              0.005705             -0.040713
# MTCH   29-Jul-19       0.001965              0.005728             -0.039613
# IDCC   29-Jul-19       0.001972              0.005691             -0.040732
# CHCO   29-Jul-19       0.001805              0.005396             -0.041225
# GOOG   29-Jul-19       0.001803              0.005379             -0.041526
# DGLY   29-Jul-19       0.001886              0.005327             -0.045778
# SLGL   29-Jul-19       0.001927              0.005410             -0.045395
# FFIC   29-Jul-19       0.001918              0.005342             -0.046589
# CYRXW  29-Jul-19       0.001920              0.005351             -0.046483
# ADP    29-Jul-19       0.001921              0.005361             -0.046271
# BPRN   29-Jul-19       0.001893              0.005409             -0.044169
# ISNS   29-Jul-19       0.001516              0.005361             -0.031439
#
#                   bollinger_long  bollinger_short  bollinger_signal
# Symbol Date
# BEAM   1-Apr-20              0.0              0.0               0.0
# DAKT   1-Apr-20              0.0              0.0               0.0
# HYACW  1-Apr-20              0.0             -1.0               0.0
# GENE   1-Apr-20              1.0              0.0              -1.0
# ESLT   1-Apr-20              0.0              0.0               1.0
# JCOM   1-Apr-20              0.0              0.0               0.0
# NDRA   1-Apr-20              0.0              0.0               0.0
# VYGR   1-Apr-20              0.0              0.0               0.0
# AEMD   1-Apr-20              0.0              0.0               0.0
# SAGE   1-Apr-20              0.0              0.0               0.0
# PSCI   1-Apr-20              0.0              0.0               0.0
# TCF    1-Apr-20              0.0              0.0               0.0
# CINF   1-Apr-20              0.0             -1.0               0.0
# NDRAW  1-Apr-20              0.0             -1.0              -1.0
# NCSM   1-Apr-20              1.0              0.0              -1.0
# ESGU   1-Apr-20              0.0              0.0               1.0
# NBSE   1-Apr-20              0.0              0.0               0.0
# SAMG   1-Apr-20              0.0              0.0               0.0
# BCYC   1-Apr-20              0.0             -1.0               0.0
# NBTB   1-Apr-20              0.0              0.0              -1.0
# PFBI   1-Apr-20              0.0              0.0               0.0
# ESGRP  1-Apr-20              0.0              0.0               0.0
# GEVO   1-Apr-20              0.0              0.0               0.0
# DAIO   1-Apr-20              0.0             -1.0               0.0
# TCCO   1-Apr-20              0.0              0.0              -1.0
# SAMAW  1-Apr-20              0.0              0.0               0.0
# VWOB   1-Apr-20              0.0              0.0               0.0
# FCAP   1-Apr-20              1.0              0.0               0.0
# CIZN   1-Apr-20              0.0              0.0               1.0
# CAMP   1-Apr-20              0.0              0.0               0.0
# ...                          ...              ...               ...
# DWFI   29-Jul-19             0.0              0.0               0.0
# ALEC   29-Jul-19             0.0             -1.0               0.0
# BRKS   29-Jul-19             0.0              0.0              -1.0
# RNDM   29-Jul-19             0.0              0.0               0.0
# DGICB  29-Jul-19             0.0              0.0               0.0
# MLVF   29-Jul-19             0.0              0.0               0.0
# CPTAG  29-Jul-19             0.0              0.0               0.0
# DISCA  29-Jul-19             0.0              0.0               0.0
# RTRX   29-Jul-19             1.0              0.0               0.0
# GXGXW  29-Jul-19             1.0              0.0               1.0
# ELTK   29-Jul-19             0.0             -1.0               1.0
# CETX   29-Jul-19             1.0              0.0              -1.0
# RGEN   29-Jul-19             0.0              0.0               1.0
# ALAC   29-Jul-19             0.0              0.0               0.0
# LACQW  29-Jul-19             0.0             -1.0               0.0
# WVVIP  29-Jul-19             0.0              0.0              -1.0
# CBAT   29-Jul-19             0.0              0.0               0.0
# FMHI   29-Jul-19             0.0              0.0               0.0
# CPRX   29-Jul-19             0.0              0.0               0.0
# MTCH   29-Jul-19             0.0              0.0               0.0
# IDCC   29-Jul-19             0.0              0.0               0.0
# CHCO   29-Jul-19             0.0              0.0               0.0
# GOOG   29-Jul-19             0.0              0.0               0.0
# DGLY   29-Jul-19             1.0              0.0               0.0
# SLGL   29-Jul-19             0.0              0.0               1.0
# FFIC   29-Jul-19             0.0              0.0               0.0
# CYRXW  29-Jul-19             0.0              0.0               0.0
# ADP    29-Jul-19             0.0              0.0               0.0
# BPRN   29-Jul-19             0.0              0.0               0.0
# ISNS   29-Jul-19             0.0              0.0               0.0
#
# [660102 rows x 17 columns]

# %%
y_train.tail()
# Out:
# Symbol  Date
# FFIC    29-Jul-19    0
# CYRXW   29-Jul-19    0
# ADP     29-Jul-19    0
# BPRN    29-Jul-19    0
# ISNS    29-Jul-19    0
# Name: Target, dtype: int64

# %%
X_test = X.iloc[660103:]
y_test = y.iloc[660103:]

X_test.tail()
# Out:
#                  fast_close  slow_close  crossover_long  crossover_short  \
# Symbol Date
# KFRC   9-Sep-19    0.014561    0.035843             0.0             -1.0
# WYNN   9-Sep-19    0.014856    0.036039             1.0              0.0
# STOK   9-Sep-19    0.013956    0.035195             0.0             -1.0
# VTGN   9-Sep-19    0.014473    0.035355             0.0             -1.0
# DOMO   9-Sep-19    0.014602    0.035378             0.0             -1.0
#
#                  crossover_signal  fast_vol  slow_vol  vol_trend_long  \
# Symbol Date
# KFRC   9-Sep-19              -1.0  0.000451  0.001937             1.0
# WYNN   9-Sep-19              -1.0  0.000437  0.001882             1.0
# STOK   9-Sep-19               1.0  0.000964  0.002017             0.0
# VTGN   9-Sep-19              -1.0  0.000860  0.001955             0.0
# DOMO   9-Sep-19              -1.0  0.000622  0.001889             1.0
#
#                  vol_trend_short  vol_trend_signal  bollinger_mid_band  \
# Symbol Date
# KFRC   9-Sep-19              0.0               1.0            0.054647
# WYNN   9-Sep-19              0.0               1.0            0.055860
# STOK   9-Sep-19             -1.0               1.0            0.055257
# VTGN   9-Sep-19             -1.0              -1.0            0.055474
# DOMO   9-Sep-19              0.0              -1.0            0.055606
#
#                  bollinger_std  bollinger_upper_band  bollinger_lower_band  \
# Symbol Date
# KFRC   9-Sep-19       0.002363              0.006707             -0.032165
# WYNN   9-Sep-19       0.002086              0.006715             -0.021840
# STOK   9-Sep-19       0.002264              0.006744             -0.027700
# VTGN   9-Sep-19       0.002262              0.006784             -0.026727
# DOMO   9-Sep-19       0.002255              0.006803             -0.026020
#
#                  bollinger_long  bollinger_short  bollinger_signal
# Symbol Date
# KFRC   9-Sep-19             0.0              0.0               0.0
# WYNN   9-Sep-19             0.0              0.0               0.0
# STOK   9-Sep-19             1.0              0.0               0.0
# VTGN   9-Sep-19             0.0              0.0               1.0
# DOMO   9-Sep-19             0.0              0.0               0.0

# %%
## Finalize the Model and Train data

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=3, random_state=0)
model.fit(X_train, y_train)

# Make a prediction of "y" values from the X_test dataset
predictions = model.predict(X_test)

# Assemble actual y data (Y_test) with predicted y data (from just above) into two columns in a dataframe:
Results = y_test.to_frame()
Results["Predicted Value"] = predictions
Results
# Out:
#                   Target  Predicted Value
# Symbol Date
# EMKR   29-Jul-19       0                0
# FLMNW  29-Jul-19       0                0
# HBCP   29-Jul-19       0                0
# PSCH   29-Jul-19       0                0
# LORL   29-Jul-19       1                1
# NBEV   29-Jul-19       0                0
# SPRT   29-Jul-19       0                0
# IMBI   29-Jul-19       0                0
# BFST   29-Jul-19       0                0
# TTTN   29-Jul-19       0                0
# IFMK   29-Jul-19       0                0
# INGN   29-Jul-19       0                0
# BL     29-Jul-19       0                0
# TKKS   29-Jul-19       0                0
# TBNK   29-Jul-19       0                0
# OSW    29-Jul-19       0                0
# CGO    29-Jul-19       0                0
# CPST   29-Jul-19       0                0
# MYOS   29-Jul-19       0                0
# FIVE   29-Jul-19       0                0
# FBMS   29-Jul-19       0                0
# OPNT   29-Jul-19       0                0
# TPIC   29-Jul-19       0                0
# ARYA   29-Jul-19       0                0
# PULM   29-Jul-19       0                0
# QADA   29-Jul-19       0                0
# BRPAW  29-Jul-19       1                1
# AVGO   29-Jul-19       0                0
# FMCIW  29-Jul-19       0                0
# SBCF   29-Jul-19       0                0
# ...                  ...              ...
# FPXE   9-Sep-19        0                0
# LPCN   9-Sep-19        1                0
# WRLSR  9-Sep-19        0                0
# BJRI   9-Sep-19        1                0
# BCPC   9-Sep-19        1                1
# TWOU   9-Sep-19        1                1
# NEO    9-Sep-19        0                0
# ALDX   9-Sep-19        0                0
# PMTS   9-Sep-19        0                0
# NXTG   9-Sep-19        0                0
# WABC   9-Sep-19        1                0
# CMLS   9-Sep-19        1                0
# TMSR   9-Sep-19        1                0
# LSXMA  9-Sep-19        0                0
# LOACR  9-Sep-19        0                0
# TRVN   9-Sep-19        1                1
# GFNSL  9-Sep-19        0                0
# CCMP   9-Sep-19        0                0
# CSGP   9-Sep-19        0                0
# SMED   9-Sep-19        1                1
# CERC   9-Sep-19        1                1
# CHSCP  9-Sep-19        0                0
# SYNH   9-Sep-19        0                0
# MESO   9-Sep-19        0                0
# MSFT   9-Sep-19        0                0
# KFRC   9-Sep-19        0                0
# WYNN   9-Sep-19        1                0
# STOK   9-Sep-19        0                0
# VTGN   9-Sep-19        1                0
# DOMO   9-Sep-19        0                0
#
# [282882 rows x 2 columns]

# %%
Results.dtypes
# Out:
# Target             int64
# Predicted Value    int64
# dtype: object

# %%
Results.tail()
# Out:
#                  Target  Predicted Value
# Symbol Date
# KFRC   9-Sep-19       0                0
# WYNN   9-Sep-19       1                0
# STOK   9-Sep-19       0                0
# VTGN   9-Sep-19       1                0
# DOMO   9-Sep-19       0                0

# %% [markdown]
# ## Print the Confusion Matrix and Classification Report to see how the Model performs

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(Results['Target'], Results['Predicted Value'])
# Out:
# array([[223806,   3296],
#        [ 21488,  34292]])

# %%
print(classification_report(Results['Target'], Results['Predicted Value']))
# Out:
# precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95    227102
#            1       0.91      0.61      0.73     55780
#
#     accuracy                           0.91    282882
#    macro avg       0.91      0.80      0.84    282882
# weighted avg       0.91      0.91      0.91    282882

# %%
importances = model.feature_importances_
importances
# Out:
# array([0.29606045, 0.08066499, 0.08172887, 0.09180067, 0.00734749,
#        0.01049065, 0.0016039 , 0.01137642, 0.01289092, 0.00457886,
#        0.03649396, 0.00282111, 0.04110576, 0.00291466, 0.00502408,
#        0.31091783, 0.00217939])

# %%
importances_df = pd.DataFrame(sorted(zip(model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True) 
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)

# %%
importances_df
# Out:
#                       Feature Importances
# 1
# bollinger_short                  0.310918
# fast_close                       0.296060
# crossover_short                  0.091801
# crossover_long                   0.081729
# slow_close                       0.080665
# bollinger_upper_band             0.041106
# bollinger_mid_band               0.036494
# vol_trend_short                  0.012891
# vol_trend_long                   0.011376
# fast_vol                         0.010491
# crossover_signal                 0.007347
# bollinger_long                   0.005024
# vol_trend_signal                 0.004579
# bollinger_lower_band             0.002915
# bollinger_std                    0.002821
# bollinger_signal                 0.002179
# slow_vol                         0.001604

# %%
# Sort importances
importances_sorted = importances_df.sort_values(by='Feature Importances')

# Draw a horizontal barplot of importances_sorted
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)

# %%
Results.reset_index(inplace=True)

# %%
Results_final = Results.groupby('Symbol').first()
# Out:
#              Date  Target  Predicted Value
# Symbol
# AACG    29-Jun-20       0                0
# AAL     29-Jun-20       1                1
# AAME    29-Jul-19       1                1
# AAOI    29-Jul-19       0                0
# AAON    29-Jul-19       0                0
# ...           ...     ...              ...
# ZSAN    29-Jul-19       0                0
# ZUMZ    29-Jul-19       0                0
# ZVO     29-Jul-19       0                0
# ZYNE    29-Jul-19       0                0
# ZYXI    29-Jul-19       1                0
#
# [3769 rows x 3 columns]

# %%
Results_final

# %%
import boto3
from os import environ as env
env['SNS_ARN'] = 'arn:aws:sns:us-west-2:585222384446:GroupProject'

# %%
def publish_message_sns(message):
    """
    :param message: str: message to be sent to SNS
    :return: None
    """
    sns_arn = env.get('SNS_ARN').strip()
    sns_client = boto3.client('sns')
    try:
        response = sns_client.publish(
            TopicArn=sns_arn,
            Message=message
        )
    except Exception as e:
        print(f"ERROR PUBLISHING MESSAGE TO SNS: {e}")

# %%
message = 'test'
publish_message_sns(message)
